# %%
# sac_target_entropy_0_json = "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_10.19.38PM_Dec-06-2020_yzt2s3s/result.json"
# sac_target_entropy_10percent_json = "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_10.03.03PM_Dec-06-2020q1genhjk/result.json"
# dqn_json = "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_09.31.13PM_Dec-06-20205sicjt44/result.json"
openspiel2 = "/home/jb/git/grl/grl/data/openspiel_kuhn_poker_11.12.56PM_Dec-09-2020.json"
openspiel1 = "/home/jb/git/grl/grl/data/openspiel_kuhn_poker_11.12.59PM_Dec-09-2020.json"
# dqn_fixed_hyperparams1 = "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_10.46.23PM_Dec-09-20209zodcqxl/result.json"
# dqn_fixed_hyperparams2 = "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_10.48.31PM_Dec-09-2020srdaskmr/result.json"
# sac_target_entropy_20percent_json = "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_10.50.47PM_Dec-09-202039mbc_wz/result.json"
# sac_target_entropy_02percent_json1 = "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_10.47.19PM_Dec-09-2020ngg9rzsq/result.json"
# sac_target_entropy_02percent_json2 = "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_10.48.48PM_Dec-09-2020_rq1s6lr/result.json"




# sac_target_entropy_10percent_bug_fixed = "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_11.06.34AM_Dec-10-20200zd_snw_/result.json"
# dqn_bug_fixed = "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_11.06.31AM_Dec-10-2020azwo4aix/result.json"
# dqn_attempt2 = "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_02.06.53PM_Dec-10-2020y98wbi3i/result.json"
# sac_attempt2 = "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_02.06.42PM_Dec-10-2020rctjnihy/result.json"
#
# sac3 = "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_03.27.02PM_Dec-10-2020uqj_73jz/result.json"
# dqn3 = "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_03.26.55PM_Dec-10-2020hd1_t5wc/result.json"
# sac4 = "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_05.48.25PM_Dec-10-202044c0hy2b/result.json"
# dqn4 = "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_05.48.30PM_Dec-10-2020cbaqvl9_/result.json"
# snfsp1 = "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_03.27.40PM_Dec-10-20208wn7b4wm/result.json"
#
# saca = "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_07.07.15PM_Dec-10-20203c_zd2po/result.json"
# saca2 = "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_08.43.43PM_Dec-10-20201pgnp8vg/result.json"

# dqn_2p = "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_03.42.02PM_Dec-14-2020d90wcyqb/result.json"
# dqn_2p_b = "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_08.14.56PM_Dec-14-2020fsx33cgh/result.json"


# rllib_2p_oracle_br = "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_02.26.48PM_Dec-15-2020gfkdr_sf/result.json"
# rllib_2p_oracle_br_small_buf = "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_08.22.59PM_Dec-15-2020akkatk_3/result.json"
# rllib_2p_oracle_br_extra_small_buf = "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_08.59.30PM_Dec-15-2020xneuxacv/result.json"

# oracle_small = "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_08.59.30PM_Dec-15-2020xneuxacv/result.json"
# oracle_medium = "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_10.50.13PM_Dec-15-2020hny66a3s/result.json"
# oracle_large = "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_10.49.19PM_Dec-15-2020wagu50x0/result.json"

oracle_fixed = "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_12.32.52PM_Dec-16-2020s_k338f8/result.json"

dqn_no_prio = "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_01.23.10PM_Dec-16-2020srazz8da/result.json"
sac_no_prio = "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_01.24.25PM_Dec-16-2020dvvbag31/result.json"


runs = {
    # "SAC target entropy 0": sac_target_entropy_0_json,
    # "SAC target entropy 0.1 * default": sac_target_entropy_10percent_json,
    # "DQN": dqn_json,
    # "DQN fixed hyperparams (seed 1)": dqn_fixed_hyperparams1,
    # "DQN fixed hyperparams (seed 2)": dqn_fixed_hyperparams2,
    "OpenSpiel Seed 1": openspiel1,
    "OpenSpiel Seed 2": openspiel2,
    # "SAC target entropy 0.02 * default (seed 1)": sac_target_entropy_02percent_json1,
    # "SAC target entropy 0.02 * default (seed 2)": sac_target_entropy_02percent_json2,
    # "SAC target entropy 0.2 * default": sac_target_entropy_20percent_json,

    #
    # "DQN (bug fixed)": dqn_bug_fixed,
    # "SAC (bug fixed) Trgt Entrpy 0.1 * default": sac_target_entropy_10percent_bug_fixed,
    # "sac 2": sac_attempt2,
    # "dqn 2": dqn_attempt2,
    # "sac3": sac3,
    # "dqn3": dqn3,
    # "snfsp1": snfsp1,
    # "sac4": sac4,
    # "dqn4": dqn4,
    # "saca": saca,
    # "saca2": saca2,

    #
    # "dqn_2p": dqn_2p,
    # "dqn_2p_b": dqn_2p_b,
    # "rllib_2p_oracle_br": rllib_2p_oracle_br,
    # "rllib_2p_oracle_br_small_buf": rllib_2p_oracle_br_small_buf,
    # "rllib_2p_oracle_br_extra_small_buf": rllib_2p_oracle_br_extra_small_buf,
    # "oracle_small": oracle_small,
    # "oracle_medium": oracle_medium,
    # "oracle_large": oracle_large,

    # "oracle_fixed": oracle_fixed,
    # "dqn_no_prio": dqn_no_prio,
    # "sac_no_prio": sac_no_prio,
    # "oracle2": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_11.39.40PM_Dec-16-20201n_5cv7m/result.json",
    # "oracle3": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_12.25.08PM_Dec-17-2020wddjbjg4/result.json",
    # "oracle4": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_12.26.43PM_Dec-17-2020_c78ob6c/result.json",
    #
    # "oracle_old_buffer": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_05.37.36PM_Dec-17-20200knvs2hb/result.json",
    # "oracle_old_buffer_fixed_rate": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_05.38.50PM_Dec-17-2020fmx30fz1/result.json",
    #
    # "oracle_old_buffer_fixed_rate_no_action_logic": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_05.19.30PM_Dec-18-2020czxce850/result.json",
    # "oracle_old_buffer_no_action_logic": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_05.19.44PM_Dec-18-2020n3cux25i/result.json",
    # "oracle_old_buffer_fixed_softmax_no_action_logic": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_07.44.18PM_Dec-18-202068colcah/result.json",
    #
    # "oracle_changed_buffer_softax_action_logic_sgd": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_12.28.04PM_Dec-19-20209hdxf4sz/result.json",
    # "oracle_changed_buffed_softmax_action_logic_sgd_no_rate_fix": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_12.34.00PM_Dec-19-20204bdj322s/result.json",
    #
    # "oracle_post_processing_added_back": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_11.36.10PM_Dec-19-2020c54q9ksw/result.json",
    # "dqn_with_working_oracle_including_post_processing": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_11.37.11PM_Dec-19-20203hx1_s8l/result.json",

    # "dqn_pace_fixed": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_06.04.33PM_Dec-16-2020toe1iqiz/result.json",
    # "dqn_pace_better_fixed": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_06.17.24PM_Dec-16-2020v54cuqnn/result.json",
    # "dqn_20x": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_08.51.05PM_Dec-16-20208sfw7pco/result.json",
    # "dqn_mse": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_12.22.20AM_Dec-17-20205pw00ys4/result.json",
    # "dqn_single_mse": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_12.28.50AM_Dec-17-2020omqyyfeq/result.json",
    # "dqn_single_mse_no_trgt": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_12.32.47AM_Dec-17-2020wf0yng9q/result.json",
    # "dqn_single_mse_SGD": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_01.07.48AM_Dec-17-2020k4sbz_hb/result.json",
    #
    # "dqn_1": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_11.08.13AM_Dec-20-2020fhqj1nwc/result.json",
    # "dqn_2": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_11.22.25AM_Dec-20-20204affg8yy/result.json",
    # "dqn_3": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_11.40.53AM_Dec-20-20209w44io2h/result.json",
    # "dqn_4": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_04.15.24PM_Dec-20-2020snmxhi6b/result.json",
    # "sac": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_05.10.19PM_Dec-20-2020cs0_3pr4/result.json",
    # "sac_low_entropy": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_12.08.50AM_Dec-21-20208253mtc_/result.json",
    # "sac_low_entropy": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_01.18.07AM_Dec-21-20208iydsgve/result.json",
    # "sac2": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_02.19.32AM_Dec-21-2020xqmirnkb/result.json",
    # "dqn_more_responsive": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_01.17.55AM_Dec-21-2020q8jtfjsd/result.json",
    # "dqn_params_matched": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_01.38.40PM_Dec-21-2020g6ju16um/result.json",
    # "dqn_matched2": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_02.30.28PM_Dec-21-2020g73biye9/result.json",


    #
    # "single dqn": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_08.19.44PM_Dec-21-2020zodj7ru4/result.json",
    # "single dqn one agent": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_08.26.37PM_Dec-21-2020l13ro3uf/result.json",
    # "single dqn twofaster epsilon anneal": '/home/jb/git/grl/grl/data/PokerMultiAgentEnv_12.13.43AM_Dec-22-2020ek_zhk12/result.json',
    "Double DQN": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_12.17.24AM_Dec-22-20201iks_zu8/result.json", # double dqn
    # "sac": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_09.18.23PM_Dec-23-202038bncjvi/result.json",
    # "sac faster tau": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_01.09.06AM_Dec-24-2020e_jywx5q/result.json",
    # "sac faster tau seed 2": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_12.42.50AM_Dec-25-2020ax8t9jsx/result.json",
    # "sac faster tau 3": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_09.41.52PM_Dec-25-2020qfxhctby/result.json",
    # "sac faster tau more entropy": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_12.24.45PM_Dec-26-2020wl6xek2b/result.json",
    "Checkpoint NFSP (every 20 sgd steps) (Retain All)": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_04.36.01PM_Dec-28-2020u531akdt/result.json",
    "Checkpoint NFSP (every 20 sgd steps) (Reservoir Buffer size 500)": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_10.40.25PM_Dec-28-2020eeng459q/result.json",
}

# %%
import json
import plotly

def parse_run_results(run_dict: dict):
    runs_to_parsed_results = {}
    for name, json_path in run_dict.items():
        runs_to_parsed_results[name] = {}
        timesteps = []
        episodes = []
        exploitability = []
        print(f"parsing {json_path}")
        with open(json_path, "r") as json_file:
            for line in json_file:
                try:
                    json_result = json.loads(s=line)
                except json.JSONDecodeError:
                    break
                timesteps_entry = json_result["timesteps_total"]
                episodes_entry = json_result["episodes_total"]
                try:
                    exploitability_entry = json_result["z_avg_policy_exploitability"]
                    if "openspiel" not in json_path:
                        for i in range(99):
                            try:
                                next(json_file)
                            except StopIteration:
                                break
                            except UnicodeDecodeError:
                                continue
                except KeyError:
                    continue

                timesteps.append(timesteps_entry)
                episodes.append(episodes_entry)
                exploitability.append(exploitability_entry)

        runs_to_parsed_results[name]["timesteps"] = timesteps
        runs_to_parsed_results[name]["episodes"] = episodes
        runs_to_parsed_results[name]["exploitability"] = exploitability
    return runs_to_parsed_results

# %%
import itertools
import pandas as pd
import plotly.express as px
import plotly.io as pio
# pio.renderers.default = 'png'
pio.renderers.default = "browser"


runs_to_parsed_results = parse_run_results(run_dict=runs)

timesteps = list(itertools.chain(*[v["timesteps"] for k, v in runs_to_parsed_results.items()]))
episodes = list(itertools.chain(*[v["episodes"] for k, v in runs_to_parsed_results.items()]))

exploitability = list(itertools.chain(*[v["exploitability"] for k, v in runs_to_parsed_results.items()]))
run = list(itertools.chain(*[[k] * len(v["exploitability"]) for k, v in runs_to_parsed_results.items()]))

in_dict = {
    "timesteps": timesteps,
    "episodes": episodes,
    "exploitability": exploitability,
    "run": run,
}

psro_runs = {
    "PSRO Double DQN (params adjusted) Seed 1": "/home/jb/git/grl/grl/data/psro_stats_kuhn_poker_10.26.07PM_Dec-28-2020.json",
    "PSRO Double DQN (params adjusted) Seed 2": "/home/jb/git/grl/grl/data/psro_stats_kuhn_poker_10.59.03PM_Dec-28-2020.json",
    "PSRO Double DQN (NFSP params)": "/home/jb/git/grl/grl/data/psro_stats_kuhn_poker_01.04.06AM_Dec-29-2020.json",
}
for run_name, data_path in psro_runs.items():
    with open(data_path, "r") as json_file:
        data = json.load(json_file)

    timesteps = data.get("timesteps") or data["total_steps"]
    episodes = data.get("episodes") or data["total_episodes"]

    assert len(timesteps) == len(episodes)
    assert len(data["exploitability"]) == len(timesteps)

    in_dict["timesteps"].extend(timesteps)
    in_dict["episodes"].extend(episodes)
    in_dict["exploitability"].extend(data["exploitability"])
    in_dict["run"].extend(run_name for _ in data["exploitability"])


df = pd.DataFrame.from_dict(data=in_dict)
fig = px.line(df, x="episodes", y="exploitability", color="run",
              title='Kuhn Poker Exploitability',
              range_x=[0, int(3e6)],
              )
fig.show()
# Out:
# parsing /home/jb/git/grl/grl/data/openspiel_kuhn_poker_11.12.59PM_Dec-09-2020.json
# parsing /home/jb/git/grl/grl/data/openspiel_kuhn_poker_11.12.56PM_Dec-09-2020.json
# parsing /home/jb/git/grl/grl/data/PokerMultiAgentEnv_12.17.24AM_Dec-22-20201iks_zu8/result.json
# parsing /home/jb/git/grl/grl/data/PokerMultiAgentEnv_04.36.01PM_Dec-28-2020u531akdt/result.json
# parsing /home/jb/git/grl/grl/data/PokerMultiAgentEnv_10.40.25PM_Dec-28-2020eeng459q/result.json

# %%
leduc_runs = {
    "openspiel seed 1": "/home/jb/git/grl/grl/data/openspiel_leduc_poker_10.12.08PM_Dec-22-2020.json",
    "double dqn seed 1": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_10.12.03PM_Dec-22-2020yn5gvkq6/result.json",
    "double dqn seed 2": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_07.20.53PM_Dec-23-2020i7hvsza5/result.json",
    "double dqn seed 3": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_12.42.52AM_Dec-25-20205o5bzc8z/result.json",
    "double dqn seed 4": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_09.41.59PM_Dec-25-2020i6v0560d/result.json",
    "double dqn seed 5": "/home/jb/git/grl/grl/data/PokerMultiAgentEnv_12.06.36AM_Dec-27-202079i55bzn/result.json",
}


import itertools
import pandas as pd
import plotly.express as px
import plotly.io as pio
# pio.renderers.default = 'png'
pio.renderers.default = "browser"


runs_to_parsed_results = parse_run_results(run_dict=leduc_runs)

timesteps = list(itertools.chain(*[v["timesteps"] for k, v in runs_to_parsed_results.items()]))
episodes = list(itertools.chain(*[v["episodes"] for k, v in runs_to_parsed_results.items()]))

exploitability = list(itertools.chain(*[v["exploitability"] for k, v in runs_to_parsed_results.items()]))
run = list(itertools.chain(*[[k] * len(v["exploitability"]) for k, v in runs_to_parsed_results.items()]))

in_dict = {
    "timesteps": timesteps,
    "episodes": episodes,
    "exploitability": exploitability,
    "run": run,
}

df = pd.DataFrame.from_dict(data=in_dict)
fig = px.line(df, x="episodes", y="exploitability", color="run",
              title='Kuhn Poker NFSP Exploitability',
              # range_x=[0, int(3e6)],
              )
fig.show()
# Out:
# parsing /home/jb/git/grl/grl/data/openspiel_leduc_poker_10.12.08PM_Dec-22-2020.json
# parsing /home/jb/git/grl/grl/data/PokerMultiAgentEnv_10.12.03PM_Dec-22-2020yn5gvkq6/result.json
# parsing /home/jb/git/grl/grl/data/PokerMultiAgentEnv_07.20.53PM_Dec-23-2020i7hvsza5/result.json
# parsing /home/jb/git/grl/grl/data/PokerMultiAgentEnv_12.42.52AM_Dec-25-20205o5bzc8z/result.json
# parsing /home/jb/git/grl/grl/data/PokerMultiAgentEnv_09.41.59PM_Dec-25-2020i6v0560d/result.json
# parsing /home/jb/git/grl/grl/data/PokerMultiAgentEnv_12.06.36AM_Dec-27-202079i55bzn/result.json
